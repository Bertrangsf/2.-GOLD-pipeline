# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df = pd.read_pickle("goldprices.pkl")
df.shape
# Out:
# (888, 5)

# %%
df_historic = df
df_historic

# %%
sns.kdeplot(x=df.year, y=df.price)
# Out:
# <AxesSubplot:xlabel='year', ylabel='price'>

# %%
df_copy = df
df_copy = df_copy.drop(df_copy[df_copy["year"] <= 2010].index)

sns.boxplot(x="year", y="price", data=df_copy)
# Out:
# <AxesSubplot:xlabel='year', ylabel='price'>

# %%
median_price_year = dfh_copy['price'].groupby(dfh_copy['year'])
table_mean = median_price_year.median().round(2)
dfh_copy2 = pd.DataFrame(table_mean)
dfh_copy2.reset_index(inplace=True)
fig = px.bar(dfh_copy2, x='year', y='price')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-be6b534b6b0d> in <module>
# ----> 1 median_price_year = dfh_copy['price'].groupby(dfh_copy['year'])
#       2 table_mean = median_price_year.median().round(2)
#       3 dfh_copy2 = pd.DataFrame(table_mean)
#       4 dfh_copy2.reset_index(inplace=True)
#       5 fig = px.bar(dfh_copy2, x='year', y='price')
#
# NameError: name 'dfh_copy' is not defined
